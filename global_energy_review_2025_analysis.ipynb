# %% [markdown]
# <a href="https://colab.research.google.com/github/raghdiness/Global-Energy/blob/main/global_energy_review_2025_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from google.colab import drive
drive.mount('/content/drive')


df_world_TES = pd.read_excel(
    '/content/drive/My Drive/Global Energy Analysis/Global Energy Review 2025 Dataset_World.xlsx',
    sheet_name='Total Energy Supply', header=2
)
df_world_TES = df_world_TES.rename(columns={df_world_TES.columns[0]: 'Fuel'})

df_world_TES.head()
df_world_TES.columns.tolist()
df_world_TES.shape
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# (6, 6)

# %%
df_world_TES = df_world_TES.rename(columns={df_world_TES.columns[0]: 'Fuel'})

# %%
df_world_TES.head()
# Out:
#           Fuel  Total Energy Supply in 2022  Total Energy Supply in 2023  \
# 0        Total                          622                          634
# 1   Renewables                           89                           92
# 2      Nuclear                           29                           30
# 3  Natural gas                          144                          145
# 4          Oil                          188                          192
#
#    Total Energy Supply in 2024  Growth rate 2022-23  Growth rate 2023-24
# 0                          648                0.018                0.022
# 1                           97                0.031                0.058
# 2                           31                0.022                0.037
# 3                          149                0.007                0.027
# 4                          193                0.019                0.008

# %%
df_world_TES['Growth rate 2022-23'] = df_world_TES['Growth rate 2022-23'].astype(float)
df_world_TES['Growth rate 2023-24'] = df_world_TES['Growth rate 2023-24'].astype(float)

# %%
df_world_TES.info()
df_world_TES.describe()
df_world_TES
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 6 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Fuel                         6 non-null      object
#  1   Total Energy Supply in 2022  6 non-null      int64
#  2   Total Energy Supply in 2023  6 non-null      int64
#  3   Total Energy Supply in 2024  6 non-null      int64
#  4   Growth rate 2022-23          6 non-null      float64
#  5   Growth rate 2023-24          6 non-null      float64
# dtypes: float64(2), int64(3), object(1)
# memory usage: 420.0+ bytes
#           Fuel  Total Energy Supply in 2022  Total Energy Supply in 2023  \
# 0        Total                          622                          634
# 1   Renewables                           89                           92
# 2      Nuclear                           29                           30
# ...

# %%
df_world_TEG = pd.read_excel(
    '/content/drive/My Drive/Global Energy Analysis/Global Energy Review 2025 Dataset_World.xlsx',
    sheet_name='Total Energy Generation',
)

df_world_TEG.head()
df_world_TEG.columns.tolist()
df_world_TEG.shape
# Out:
# (8, 6)

# %%
df_world_TEG.head()
# Out:
#    Unnamed: 0                            Unnamed: 1  \
# 0         NaN                                   NaN
# 1         NaN  Electricity generation (TWh) in 2022
# 2       Total                                 29153
# 3  Renewables                                  8643
# 4     Nuclear                                  2684
#
#                              Unnamed: 2                            Unnamed: 3  \
# 0                                   NaN                                   NaN
# 1  Electricity generation (TWh) in 2023  Electricity generation (TWh) in 2024
# 2                                 29897                                 31153
# 3                                  9074                                  9992
# 4                                  2743                                  2844
#
#             Unnamed: 4           Unnamed: 5
# 0                  NaN                  NaN
# 1  Growth rate 2022-23  Growth rate 2023-24
# 2                0.026                0.042
# ...
